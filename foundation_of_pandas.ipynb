# %% [markdown]
# <a href="https://colab.research.google.com/github/sairam178/Foundation-of-machine-learning/blob/main/foundation_of_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, 6, 8])
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %% [markdown]
# indexing with our own type

# %%
s= pd.Series([1,2,3],index=["s","a","i"])
print(s)
print(s[0])
print(s["a"])
# Out:
# s    1
# a    2
# i    3
# dtype: int64
# 1
# 2
# /tmp/ipython-input-398/872365538.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[0])

# %% [markdown]
# series from Dictionary

# %%
data = {"math":90,"physics":49,"chemistry":99}
marks  = pd.Series(data)
print(data)
print()
print(marks)
# Out:
# {'math': 90, 'physics': 49, 'chemistry': 99}
#
# math         90
# physics      49
# chemistry    99
# dtype: int64

# %% [markdown]
# DataFrame in pandas

# %%
data = {
    "Name":["SAIRAM","sriram","jairam"],
    "Age":[21,22,23],
    "marks":[99,97,8]
}
print(data)
marks = pd.DataFrame(data)
print(marks)
# Out:
# {'Name': ['SAIRAM', 'sriram', 'jairam'], 'Age': [21, 22, 23], 'marks': [99, 97, 8]}
#      Name  Age  marks
# 0  SAIRAM   21     99
# 1  sriram   22     97
# 2  jairam   23      8

# %%
marks = pd.DataFrame(
    data,
    index = ["student1","student2","student3"]
)
print(marks)
# Out:
#             Name  Age  marks
# student1  SAIRAM   21     99
# student2  sriram   22     97
# student3  jairam   23      8

# %%
marks.set_index("Name", inplace=True) # if we setting palce = ture it means we changing the orginal objectitself
print(marks)
# Out:
#         Age  marks
# Name
# SAIRAM   21     99
# sriram   22     97
# jairam   23      8

# %%
df = pd.DataFrame({
    "Name":["aman","roman","karun"],
    "age":[22,23,21],
    "marks":[86,4,65]
})
print(df)
df.head() # as the no of rows is less thyan 5 so the output of both df head front
df.tail() # print least 5 rows from data
# Out:
#     Name  age  marks
# 0   aman   22     86
# 1  roman   23      4
# 2  karun   21     65
#     Name  age  marks
# 0   aman   22     86
# 1  roman   23      4
# 2  karun   21     65

# %%
df = pd.DataFrame({
     "Name":["aman","roman","karun","sam","ramu"],
    "age":[22,23,21,23,44],
    "marks":[86,4,65,234,55]
})

df.tail(2)
# Out:
#    Name  age  marks
# 3   sam   23    234
# 4  ramu   44     55

# %%
df.head(2)
# Out:
#     Name  age  marks
# 0   aman   22     86
# 1  roman   23      4

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['Name', 'age', 'marks'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   age     5 non-null      int64
#  2   marks   5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df.describe()
# Out:
#              age      marks
# count   5.000000    5.00000
# mean   26.600000   88.80000
# std     9.762172   86.58926
# min    21.000000    4.00000
# 25%    22.000000   55.00000
# 50%    23.000000   65.00000
# 75%    23.000000   86.00000
# max    44.000000  234.00000

# %% [markdown]
# Selecting the data

# %%
df["Name"]
# Out:
# 0     aman
# 1    roman
# 2    karun
# 3      sam
# 4     ramu
# Name: Name, dtype: object

# %%
df["age"]
# Out:
# 0    22
# 1    23
# 2    21
# 3    23
# 4    44
# Name: age, dtype: int64

# %%
df[["Name","age"]]
# Out:
#     Name  age
# 0   aman   22
# 1  roman   23
# 2  karun   21
# 3    sam   23
# 4   ramu   44

# %% [markdown]
# Filtering in Pandas

# %%
df[df["marks"]>85]
# Out:
#    Name  age  marks
# 0  aman   22     86
# 3   sam   23    234

# %%
df[(df["age"]>21)&(df["marks"]>55)]
# Out:
#    Name  age  marks
# 0  aman   22     86
# 3   sam   23    234

# %% [markdown]
# Sorting +Value Counts

# %%
df.sort_values("marks")
# Out:
#     Name  age  marks
# 1  roman   23      4
# 4   ramu   44     55
# 2  karun   21     65
# 0   aman   22     86
# 3    sam   23    234

# %%
df.sort_values("marks",ascending=False)
# Out:
#     Name  age  marks
# 3    sam   23    234
# 0   aman   22     86
# 2  karun   21     65
# 4   ramu   44     55
# 1  roman   23      4

# %%
df["age"].value_counts()
# Out:
# age
# 23    2
# 22    1
# 21    1
# 44    1
# Name: count, dtype: int64

# %% [markdown]
# Handling missing values

# %%
df = pd.DataFrame({
    "Name":["aman","roman","karun",None,"sam","ramu"],
    "age":[22,23,21,None,25,67],
    "Marks":[86,4,65,None,234,55]
})

df
# Out:
#     Name   age  Marks
# 0   aman  22.0   86.0
# 1  roman  23.0    4.0
# 2  karun  21.0   65.0
# 3   None   NaN    NaN
# 4    sam  25.0  234.0
# 5   ramu  67.0   55.0

# %%
df.isnull()
# Out:
#     Name    age  Marks
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3   True   True   True
# 4  False  False  False
# 5  False  False  False

# %%
df.isnull().sum()
# Out:
# Name     1
# age      1
# Marks    1
# dtype: int64

# %%
df.dropna()
# Out:
#     Name   age  Marks
# 0   aman  22.0   86.0
# 1  roman  23.0    4.0
# 2  karun  21.0   65.0
# 4    sam  25.0  234.0
# 5   ramu  67.0   55.0

# %%
print(df)
# Out:
#     Name   age  Marks
# 0   aman  22.0   86.0
# 1  roman  23.0    4.0
# 2  karun  21.0   65.0
# 3   None   NaN    NaN
# 4    sam  25.0  234.0
# 5   ramu  67.0   55.0
